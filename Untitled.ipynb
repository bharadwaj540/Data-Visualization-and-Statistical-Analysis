# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
os.chdir('E:\\')
data=pd.read_excel('solar data 1.0.xlsx',sheet_name='Sheet1')
data.head(3)
# Out:
#         dates  VIT-A(100KWp)  VIT-B(100.8KWp)  POLY.(100.8KWp)  \
# 0  01.01.2018          267.3            358.2            350.4
# 1  02.01.2018          378.1            423.6            423.0
# 2  03.01.2018          388.1            435.8            434.0
#
#    WOMEN(50.4KWp)  VDC(50KWp)  PHARM(50.4KWp)  BVRICE(50KWp)  Day wise total
# 0           165.8       139.1           157.0          129.3          1567.1
# 1           196.0       164.1           189.8          179.8          1954.4
# 2           200.5       167.6           194.4          186.1          3521.5

# %%
l=['VIT-A(100KWp)','VIT-B(100.8KWp)','POLY.(100.8KWp)']
plt.figure(figsize=(15,5))
a=[data[i].sum() for i in l]
print(a)
plt.bar(l,a)
plt.show()
# Out:
# [212763.03, 278418.1, 281656.66000000003]

# %%
data['dates']=pd.to_datetime(data['dates'],format='%d-%m-%Y')

# %%
data['Month']=data['dates'].dt.month

# %%
data
# Out:
#          dates  VIT-A(100KWp)  VIT-B(100.8KWp)  POLY.(100.8KWp)  \
# 0   2018-01-01         267.30           358.20           350.40
# 1   2018-02-01         378.10           423.60           423.00
# 2   2018-03-01         388.10           435.80           434.00
# 3   2018-04-01         285.90           438.70           435.60
# 4   2018-05-01         335.80           458.50           453.00
# 5   2018-06-01         404.20            11.20            11.10
# 6   2018-07-01         281.50           442.00           443.10
# 7   2018-08-01         441.60           434.60           431.90
# 8   2018-09-01         438.20           425.00           424.00
# 9   2018-10-01         417.10           431.30           427.30
# 10  2018-11-01         347.60           408.20           403.90
# 11  2018-12-01         269.20           364.80           361.10
# 12  2018-01-13         312.90           352.20           343.20
# 13  2018-01-14         136.90           294.70           291.40
# ...

# %%
c=data.groupby(['Month'])['VIT-A(100KWp)'].sum()
c=list(c)
print(c)
# Out:
# [16201.45, 14380.720000000003, 10924.5, 11658.419999999998, 4276.22, 9876.52, 9991.259999999998, 9237.43, 9928.77, 10537.190000000002, 9998.360000000002, 9849.66]

# %%
b=['January','February','March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
plt.bar(b,c)
plt.xlabel('MONTHS', fontsize=15)
plt.ylabel('units produced', fontsize=20)
plt.xticks(b, fontsize=10, rotation=90)
plt.yticks(fontsize=10)
plt.title('no. of units produced per month in vit-A',fontsize=30)
plt.show()

# %%
b = ['January','February','March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']);
b = reorder(b,{'January','February','March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'});
plt.bar(b,c)
plt.show()
# Out:
#   File "<ipython-input-121-5a92d748692d>", line 1
#     b = ['January','February','March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']);
#                                                                                                                                 ^
# SyntaxError: invalid syntax

# %%
rec=pd.read_excel('DATA2017.xlsx',sheet_name='Sheet2')

# %%
li=['BVRICE','VDC','VIT']
mi=['BVRICE(50KWp)','VDC(50KWp)','VIT-A(100KWp)']
y=['2017','2018']
barWidth = 0.25
bar1=[rec[i].sum() for i in li]
bar2=[data[i].sum() for i in mi]
r1 = np.arange(len(bar1))
r2 = [x + barWidth for x in r1]
plt.bar(r1, bar1, color='r', width=barWidth, edgecolor='white', label='2017')
plt.bar(r2, bar2, color='b', width=barWidth, edgecolor='white', label='2018')
plt.xticks([r + barWidth for r in range(len(bar1))],mi)
plt.legend()
plt.show()

# %%
a2[['mi','b','z']].plot(x='mi',kind='bar',width=0.8,figsize=(15,5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-134-eecd5f09d75d> in <module>()
# ----> 1 a2[['y','b',z]].plot(x='li',kind='bar',width=0.8,figsize=(15,5))
#
# NameError: name 'a2' is not defined
